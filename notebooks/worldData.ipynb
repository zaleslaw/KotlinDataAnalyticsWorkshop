// %%
import org.jetbrains.kotlinx.dataframe.DataFrame
import org.jetbrains.kotlinx.dataframe.api.head
import org.jetbrains.kotlinx.dataframe.io.readCSV

var df = DataFrame.readCSV(fileOrUrl = "../src/main/resources/world-data-2023.csv", delimiter = ',')

df.head()
// Out:
// The problem is found in one of the loaded libraries: check library converters (fields callbacks)
// Error compiling code:
// @DataSchema
// interface _DataFrameType { }
//
// val ColumnsContainer<_DataFrameType>.Abbreviation: DataColumn<String?> @JvmName("_DataFrameType_Abbreviation") get() = this["Abbreviation"] as DataColumn<String?>
// val DataRow<_DataFrameType>.Abbreviation: String? @JvmName("_DataFrameType_Abbreviation") get() = this["Abbreviation"] as String?
// val ColumnsContainer<_DataFrameType?>.Abbreviation: DataColumn<String?> @JvmName("Nullable_DataFrameType_Abbreviation") get() = this["Abbreviation"] as DataColumn<String?>
// val DataRow<_DataFrameType?>.Abbreviation: String? @JvmName("Nullable_DataFrameType_Abbreviation") get() = this["Abbreviation"] as String?
// val ColumnsContainer<_DataFrameType>.CPI: DataColumn<Double?> @JvmName("_DataFrameType_CPI") get() = this["CPI"] as DataColumn<Double?>
// val DataRow<_DataFrameType>.CPI: Double? @JvmName("_DataFrameType_CPI") get() = this["CPI"] as Double?
// val ColumnsContainer<_DataFrameType?>.CPI: DataColumn<Double?> @JvmName("Nullable_DataFrameType_CPI") get() = this["CPI"] as DataColumn<Double?>
// val DataRow<_DataFrameType?>.CPI: Double? @JvmName("Nullable_DataFrameType_CPI") get() = this["CPI"] as Double?
// val ColumnsContainer<_DataFrameType>.Country: DataColumn<String> @JvmName("_DataFrameType_Country") get() = this["Country"] as DataColumn<String>
// val DataRow<_DataFrameType>.Country: String @JvmName("_DataFrameType_Country") get() = this["Country"] as String
// val ColumnsContainer<_DataFrameType?>.Country: DataColumn<String?> @JvmName("Nullable_DataFrameType_Country") get() = this["Country"] as DataColumn<String?>
// val DataRow<_DataFrameType?>.Country: String? @JvmName("Nullable_DataFrameType_Country") get() = this["Country"] as String?
// val ColumnsContainer<_DataFrameType>.GDP: DataColumn<String?> @JvmName("_DataFrameType_GDP") get() = this["GDP"] as DataColumn<String?>
// val DataRow<_DataFrameType>.GDP: String? @JvmName("_DataFrameType_GDP") get() = this["GDP"] as String?
// val ColumnsContainer<_DataFrameType?>.GDP: DataColumn<String?> @JvmName("Nullable_DataFrameType_GDP") get() = this["GDP"] as DataColumn<String?>
// val DataRow<_DataFrameType?>.GDP: String? @JvmName("Nullable_DataFrameType_GDP") get() = this["GDP"] as String?
// val ColumnsContainer<_DataFrameType>.Latitude: DataColumn<Double?> @JvmName("_DataFrameType_Latitude") get() = this["Latitude"] as DataColumn<Double?>
// val DataRow<_DataFrameType>.Latitude: Double? @JvmName("_DataFrameType_Latitude") get() = this["Latitude"] as Double?
// val ColumnsContainer<_DataFrameType?>.Latitude: DataColumn<Double?> @JvmName("Nullable_DataFrameType_Latitude") get() = this["Latitude"] as DataColumn<Double?>
// val DataRow<_DataFrameType?>.Latitude: Double? @JvmName("Nullable_DataFrameType_Latitude") get() = this["Latitude"] as Double?
// val ColumnsContainer<_DataFrameType>.Longitude: DataColumn<Double?> @JvmName("_DataFrameType_Longitude") get() = this["Longitude"] as DataColumn<Double?>
// val DataRow<_DataFrameType>.Longitude: Double? @JvmName("_DataFrameType_Longitude") get() = this["Longitude"] as Double?
// val ColumnsContainer<_DataFrameType?>.Longitude: DataColumn<Double?> @JvmName("Nullable_DataFrameType_Longitude") get() = this["Longitude"] as DataColumn<Double?>
// val DataRow<_DataFrameType?>.Longitude: Double? @JvmName("Nullable_DataFrameType_Longitude") get() = this["Longitude"] as Double?
// val ColumnsContainer<_DataFrameType>.Population: DataColumn<Double?> @JvmName("_DataFrameType_Population") get() = this["Population"] as DataColumn<Double?>
// val DataRow<_DataFrameType>.Population: Double? @JvmName("_DataFrameType_Population") get() = this["Population"] as Double?
// val ColumnsContainer<_DataFrameType?>.Population: DataColumn<Double?> @JvmName("Nullable_DataFrameType_Population") get() = this["Population"] as DataColumn<Double?>
// val DataRow<_DataFrameType?>.Population: Double? @JvmName("Nullable_DataFrameType_Population") get() = this["Population"] as Double?
// val ColumnsContainer<_DataFrameType>.Urban_population: DataColumn<Double?> @JvmName("_DataFrameType_Urban_population") get() = this["Urban_population"] as DataColumn<Double?>
// val DataRow<_DataFrameType>.Urban_population: Double? @JvmName("_DataFrameType_Urban_population") get() = this["Urban_population"] as Double?
// val ColumnsContainer<_DataFrameType?>.Urban_population: DataColumn<Double?> @JvmName("Nullable_DataFrameType_Urban_population") get() = this["Urban_population"] as DataColumn<Double?>
// val DataRow<_DataFrameType?>.Urban_population: Double? @JvmName("Nullable_DataFrameType_Urban_population") get() = this["Urban_population"] as Double?
// val ColumnsContainer<_DataFrameType>.`Agricultural Land( %)`: DataColumn<String?> @JvmName("_DataFrameType_Agricultural Land( %)") get() = this["Agricultural Land( %)"] as DataColumn<String?>
// val DataRow<_DataFrameType>.`Agricultural Land( %)`: String? @JvmName("_DataFrameType_Agricultural Land( %)") get() = this["Agricultural Land( %)"] as String?
// val ColumnsContainer<_DataFrameType?>.`Agricultural Land( %)`: DataColumn<String?> @JvmName("Nullable_DataFrameType_Agricultural Land( %)") get() = this["Agricultural Land( %)"] as DataColumn<String?>
// val DataRow<_DataFrameType?>.`Agricultural Land( %)`: String? @JvmName("Nullable_DataFrameType_Agricultural Land( %)") get() = this["Agricultural Land( %)"] as String?
// val ColumnsContainer<_DataFrameType>.`Armed Forces size`: DataColumn<Double?> @JvmName("_DataFrameType_Armed Forces size") get() = this["Armed Forces size"] as DataColumn<Double?>
// val DataRow<_DataFrameType>.`Armed Forces size`: Double? @JvmName("_DataFrameType_Armed Forces size") get() = this["Armed Forces size"] as Double?
// val ColumnsContainer<_DataFrameType?>.`Armed Forces size`: DataColumn<Double?> @JvmName("Nullable_DataFrameType_Armed Forces size") get() = this["Armed Forces size"] as DataColumn<Double?>
// val DataRow<_DataFrameType?>.`Armed Forces size`: Double? @JvmName("Nullable_DataFrameType_Armed Forces size") get() = this["Armed Forces size"] as Double?
// val ColumnsContainer<_DataFrameType>.`Birth Rate`: DataColumn<Double?> @JvmName("_DataFrameType_Birth Rate") get() = this["Birth Rate"] as DataColumn<Double?>
// val DataRow<_DataFrameType>.`Birth Rate`: Double? @JvmName("_DataFrameType_Birth Rate") get() = this["Birth Rate"] as Double?
// val ColumnsContainer<_DataFrameType?>.`Birth Rate`: DataColumn<Double?> @JvmName("Nullable_DataFrameType_Birth Rate") get() = this["Birth Rate"] as DataColumn<Double?>
// val DataRow<_DataFrameType?>.`Birth Rate`: Double? @JvmName("Nullable_DataFrameType_Birth Rate") get() = this["Birth Rate"] as Double?
// val ColumnsContainer<_DataFrameType>.`CPI Change (%)`: DataColumn<String?> @JvmName("_DataFrameType_CPI Change (%)") get() = this["CPI Change (%)"] as DataColumn<String?>
// val DataRow<_DataFrameType>.`CPI Change (%)`: String? @JvmName("_DataFrameType_CPI Change (%)") get() = this["CPI Change (%)"] as String?
// val ColumnsContainer<_DataFrameType?>.`CPI Change (%)`: DataColumn<String?> @JvmName("Nullable_DataFrameType_CPI Change (%)") get() = this["CPI Change (%)"] as DataColumn<String?>
// val DataRow<_DataFrameType?>.`CPI Change (%)`: String? @JvmName("Nullable_DataFrameType_CPI Change (%)") get() = this["CPI Change (%)"] as String?
// val ColumnsContainer<_DataFrameType>.`Calling Code`: DataColumn<Int?> @JvmName("_DataFrameType_Calling Code") get() = this["Calling Code"] as DataColumn<Int?>
// val DataRow<_DataFrameType>.`Calling Code`: Int? @JvmName("_DataFrameType_Calling Code") get() = this["Calling Code"] as Int?
// val ColumnsContainer<_DataFrameType?>.`Calling Code`: DataColumn<Int?> @JvmName("Nullable_DataFrameType_Calling Code") get() = this["Calling Code"] as DataColumn<Int?>
// val DataRow<_DataFrameType?>.`Calling Code`: Int? @JvmName("Nullable_DataFrameType_Calling Code") get() = this["Calling Code"] as Int?
// val ColumnsContainer<_DataFrameType>.`Capital-Major City`: DataColumn<String?> @JvmName("_DataFrameType_Capital-Major City") get() = this["Capital/Major City"] as DataColumn<String?>
// val DataRow<_DataFrameType>.`Capital-Major City`: String? @JvmName("_DataFrameType_Capital-Major City") get() = this["Capital/Major City"] as String?
// val ColumnsContainer<_DataFrameType?>.`Capital-Major City`: DataColumn<String?> @JvmName("Nullable_DataFrameType_Capital-Major City") get() = this["Capital/Major City"] as DataColumn<String?>
// val DataRow<_DataFrameType?>.`Capital-Major City`: String? @JvmName("Nullable_DataFrameType_Capital-Major City") get() = this["Capital/Major City"] as String?
// val ColumnsContainer<_DataFrameType>.`Co2-Emissions`: DataColumn<Double?> @JvmName("_DataFrameType_Co2-Emissions") get() = this["Co2-Emissions"] as DataColumn<Double?>
// val DataRow<_DataFrameType>.`Co2-Emissions`: Double? @JvmName("_DataFrameType_Co2-Emissions") get() = this["Co2-Emissions"] as Double?
// val ColumnsContainer<_DataFrameType?>.`Co2-Emissions`: DataColumn<Double?> @JvmName("Nullable_DataFrameType_Co2-Emissions") get() = this["Co2-Emissions"] as DataColumn<Double?>
// val DataRow<_DataFrameType?>.`Co2-Emissions`: Double? @JvmName("Nullable_DataFrameType_Co2-Emissions") get() = this["Co2-Emissions"] as Double?
// val ColumnsContainer<_DataFrameType>.`Currency-Code`: DataColumn<String?> @JvmName("_DataFrameType_Currency-Code") get() = this["Currency-Code"] as DataColumn<String?>
// val DataRow<_DataFrameType>.`Currency-Code`: String? @JvmName("_DataFrameType_Currency-Code") get() = this["Currency-Code"] as String?
// val ColumnsContainer<_DataFrameType?>.`Currency-Code`: DataColumn<String?> @JvmName("Nullable_DataFrameType_Currency-Code") get() = this["Currency-Code"] as DataColumn<String?>
// val DataRow<_DataFrameType?>.`Currency-Code`: String? @JvmName("Nullable_DataFrameType_Currency-Code") get() = this["Currency-Code"] as String?
// val ColumnsContainer<_DataFrameType>.`Density
// (P-Km2)`: DataColumn<Double> @JvmName("_DataFrameType_Density
// (P-Km2)") get() = this["Density
// (P/Km2)"] as DataColumn<Double>
// val DataRow<_DataFrameType>.`Density
// (P-Km2)`: Double @JvmName("_DataFrameType_Density
// (P-Km2)") get() = this["Density
// (P/Km2)"] as Double
// val ColumnsContainer<_DataFrameType?>.`Density
// (P-Km2)`: DataColumn<Double?> @JvmName("Nullable_DataFrameType_Density
// (P-Km2)") get() = this["Density
// (P/Km2)"] as DataColumn<Double?>
// val DataRow<_DataFrameType?>.`Density
// (P-Km2)`: Double? @JvmName("Nullable_DataFrameType_Density
// (P-Km2)") get() = this["Density
// (P/Km2)"] as Double?
// val ColumnsContainer<_DataFrameType>.`Fertility Rate`: DataColumn<Double?> @JvmName("_DataFrameType_Fertility Rate") get() = this["Fertility Rate"] as DataColumn<Double?>
// val DataRow<_DataFrameType>.`Fertility Rate`: Double? @JvmName("_DataFrameType_Fertility Rate") get() = this["Fertility Rate"] as Double?
// val ColumnsContainer<_DataFrameType?>.`Fertility Rate`: DataColumn<Double?> @JvmName("Nullable_DataFrameType_Fertility Rate") get() = this["Fertility Rate"] as DataColumn<Double?>
// val DataRow<_DataFrameType?>.`Fertility Rate`: Double? @JvmName("Nullable_DataFrameType_Fertility Rate") get() = this["Fertility Rate"] as Double?
// val ColumnsContainer<_DataFrameType>.`Forested Area (%)`: DataColumn<String?> @JvmName("_DataFrameType_Forested Area (%)") get() = this["Forested Area (%)"] as DataColumn<String?>
// val DataRow<_DataFrameType>.`Forested Area (%)`: String? @JvmName("_DataFrameType_Forested Area (%)") get() = this["Forested Area (%)"] as String?
// val ColumnsContainer<_DataFrameType?>.`Forested Area (%)`: DataColumn<String?> @JvmName("Nullable_DataFrameType_Forested Area (%)") get() = this["Forested Area (%)"] as DataColumn<String?>
// val DataRow<_DataFrameType?>.`Forested Area (%)`: String? @JvmName("Nullable_DataFrameType_Forested Area (%)") get() = this["Forested Area (%)"] as String?
// val ColumnsContainer<_DataFrameType>.`Gasoline Price`: DataColumn<String?> @JvmName("_DataFrameType_Gasoline Price") get() = this["Gasoline Price"] as DataColumn<String?>
// val DataRow<_DataFrameType>.`Gasoline Price`: String? @JvmName("_DataFrameType_Gasoline Price") get() = this["Gasoline Price"] as String?
// val ColumnsContainer<_DataFrameType?>.`Gasoline Price`: DataColumn<String?> @JvmName("Nullable_DataFrameType_Gasoline Price") get() = this["Gasoline Price"] as DataColumn<String?>
// val DataRow<_DataFrameType?>.`Gasoline Price`: String? @JvmName("Nullable_DataFrameType_Gasoline Price") get() = this["Gasoline Price"] as String?
// val ColumnsContainer<_DataFrameType>.`Gross primary education enrollment (%)`: DataColumn<String?> @JvmName("_DataFrameType_Gross primary education enrollment (%)") get() = this["Gross primary education enrollment (%)"] as DataColumn<String?>
// val DataRow<_DataFrameType>.`Gross primary education enrollment (%)`: String? @JvmName("_DataFrameType_Gross primary education enrollment (%)") get() = this["Gross primary education enrollment (%)"] as String?
// val ColumnsContainer<_DataFrameType?>.`Gross primary education enrollment (%)`: DataColumn<String?> @JvmName("Nullable_DataFrameType_Gross primary education enrollment (%)") get() = this["Gross primary education enrollment (%)"] as DataColumn<String?>
// val DataRow<_DataFrameType?>.`Gross primary education enrollment (%)`: String? @JvmName("Nullable_DataFrameType_Gross primary education enrollment (%)") get() = this["Gross primary education enrollment (%)"] as String?
// val ColumnsContainer<_DataFrameType>.`Gross tertiary education enrollment (%)`: DataColumn<String?> @JvmName("_DataFrameType_Gross tertiary education enrollment (%)") get() = this["Gross tertiary education enrollment (%)"] as DataColumn<String?>
// val DataRow<_DataFrameType>.`Gross tertiary education enrollment (%)`: String? @JvmName("_DataFrameType_Gross tertiary education enrollment (%)") get() = this["Gross tertiary education enrollment (%)"] as String?
// val ColumnsContainer<_DataFrameType?>.`Gross tertiary education enrollment (%)`: DataColumn<String?> @JvmName("Nullable_DataFrameType_Gross tertiary education enrollment (%)") get() = this["Gross tertiary education enrollment (%)"] as DataColumn<String?>
// val DataRow<_DataFrameType?>.`Gross tertiary education enrollment (%)`: String? @JvmName("Nullable_DataFrameType_Gross tertiary education enrollment (%)") get() = this["Gross tertiary education enrollment (%)"] as String?
// val ColumnsContainer<_DataFrameType>.`Infant mortality`: DataColumn<Double?> @JvmName("_DataFrameType_Infant mortality") get() = this["Infant mortality"] as DataColumn<Double?>
// val DataRow<_DataFrameType>.`Infant mortality`: Double? @JvmName("_DataFrameType_Infant mortality") get() = this["Infant mortality"] as Double?
// val ColumnsContainer<_DataFrameType?>.`Infant mortality`: DataColumn<Double?> @JvmName("Nullable_DataFrameType_Infant mortality") get() = this["Infant mortality"] as DataColumn<Double?>
// val DataRow<_DataFrameType?>.`Infant mortality`: Double? @JvmName("Nullable_DataFrameType_Infant mortality") get() = this["Infant mortality"] as Double?
// val ColumnsContainer<_DataFrameType>.`Land Area(Km2)`: DataColumn<Double?> @JvmName("_DataFrameType_Land Area(Km2)") get() = this["Land Area(Km2)"] as DataColumn<Double?>
// val DataRow<_DataFrameType>.`Land Area(Km2)`: Double? @JvmName("_DataFrameType_Land Area(Km2)") get() = this["Land Area(Km2)"] as Double?
// val ColumnsContainer<_DataFrameType?>.`Land Area(Km2)`: DataColumn<Double?> @JvmName("Nullable_DataFrameType_Land Area(Km2)") get() = this["Land Area(Km2)"] as DataColumn<Double?>
// val DataRow<_DataFrameType?>.`Land Area(Km2)`: Double? @JvmName("Nullable_DataFrameType_Land Area(Km2)") get() = this["Land Area(Km2)"] as Double?
// val ColumnsContainer<_DataFrameType>.`Largest city`: DataColumn<String?> @JvmName("_DataFrameType_Largest city") get() = this["Largest city"] as DataColumn<String?>
// val DataRow<_DataFrameType>.`Largest city`: String? @JvmName("_DataFrameType_Largest city") get() = this["Largest city"] as String?
// val ColumnsContainer<_DataFrameType?>.`Largest city`: DataColumn<String?> @JvmName("Nullable_DataFrameType_Largest city") get() = this["Largest city"] as DataColumn<String?>
// val DataRow<_DataFrameType?>.`Largest city`: String? @JvmName("Nullable_DataFrameType_Largest city") get() = this["Largest city"] as String?
// val ColumnsContainer<_DataFrameType>.`Life expectancy`: DataColumn<Double?> @JvmName("_DataFrameType_Life expectancy") get() = this["Life expectancy"] as DataColumn<Double?>
// val DataRow<_DataFrameType>.`Life expectancy`: Double? @JvmName("_DataFrameType_Life expectancy") get() = this["Life expectancy"] as Double?
// val ColumnsContainer<_DataFrameType?>.`Life expectancy`: DataColumn<Double?> @JvmName("Nullable_DataFrameType_Life expectancy") get() = this["Life expectancy"] as DataColumn<Double?>
// val DataRow<_DataFrameType?>.`Life expectancy`: Double? @JvmName("Nullable_DataFrameType_Life expectancy") get() = this["Life expectancy"] as Double?
// val ColumnsContainer<_DataFrameType>.`Maternal mortality ratio`: DataColumn<Int?> @JvmName("_DataFrameType_Maternal mortality ratio") get() = this["Maternal mortality ratio"] as DataColumn<Int?>
// val DataRow<_DataFrameType>.`Maternal mortality ratio`: Int? @JvmName("_DataFrameType_Maternal mortality ratio") get() = this["Maternal mortality ratio"] as Int?
// val ColumnsContainer<_DataFrameType?>.`Maternal mortality ratio`: DataColumn<Int?> @JvmName("Nullable_DataFrameType_Maternal mortality ratio") get() = this["Maternal mortality ratio"] as DataColumn<Int?>
// val DataRow<_DataFrameType?>.`Maternal mortality ratio`: Int? @JvmName("Nullable_DataFrameType_Maternal mortality ratio") get() = this["Maternal mortality ratio"] as Int?
// val ColumnsContainer<_DataFrameType>.`Minimum wage`: DataColumn<String?> @JvmName("_DataFrameType_Minimum wage") get() = this["Minimum wage"] as DataColumn<String?>
// val DataRow<_DataFrameType>.`Minimum wage`: String? @JvmName("_DataFrameType_Minimum wage") get() = this["Minimum wage"] as String?
// val ColumnsContainer<_DataFrameType?>.`Minimum wage`: DataColumn<String?> @JvmName("Nullable_DataFrameType_Minimum wage") get() = this["Minimum wage"] as DataColumn<String?>
// val DataRow<_DataFrameType?>.`Minimum wage`: String? @JvmName("Nullable_DataFrameType_Minimum wage") get() = this["Minimum wage"] as String?
// val ColumnsContainer<_DataFrameType>.`Official language`: DataColumn<String?> @JvmName("_DataFrameType_Official language") get() = this["Official language"] as DataColumn<String?>
// val DataRow<_DataFrameType>.`Official language`: String? @JvmName("_DataFrameType_Official language") get() = this["Official language"] as String?
// val ColumnsContainer<_DataFrameType?>.`Official language`: DataColumn<String?> @JvmName("Nullable_DataFrameType_Official language") get() = this["Official language"] as DataColumn<String?>
// val DataRow<_DataFrameType?>.`Official language`: String? @JvmName("Nullable_DataFrameType_Official language") get() = this["Official language"] as String?
// val ColumnsContainer<_DataFrameType>.`Out of pocket health expenditure`: DataColumn<String?> @JvmName("_DataFrameType_Out of pocket health expenditure") get() = this["Out of pocket health expenditure"] as DataColumn<String?>
// val DataRow<_DataFrameType>.`Out of pocket health expenditure`: String? @JvmName("_DataFrameType_Out of pocket health expenditure") get() = this["Out of pocket health expenditure"] as String?
// val ColumnsContainer<_DataFrameType?>.`Out of pocket health expenditure`: DataColumn<String?> @JvmName("Nullable_DataFrameType_Out of pocket health expenditure") get() = this["Out of pocket health expenditure"] as DataColumn<String?>
// val DataRow<_DataFrameType?>.`Out of pocket health expenditure`: String? @JvmName("Nullable_DataFrameType_Out of pocket health expenditure") get() = this["Out of pocket health expenditure"] as String?
// val ColumnsContainer<_DataFrameType>.`Physicians per thousand`: DataColumn<Double?> @JvmName("_DataFrameType_Physicians per thousand") get() = this["Physicians per thousand"] as DataColumn<Double?>
// val DataRow<_DataFrameType>.`Physicians per thousand`: Double? @JvmName("_DataFrameType_Physicians per thousand") get() = this["Physicians per thousand"] as Double?
// val ColumnsContainer<_DataFrameType?>.`Physicians per thousand`: DataColumn<Double?> @JvmName("Nullable_DataFrameType_Physicians per thousand") get() = this["Physicians per thousand"] as DataColumn<Double?>
// val DataRow<_DataFrameType?>.`Physicians per thousand`: Double? @JvmName("Nullable_DataFrameType_Physicians per thousand") get() = this["Physicians per thousand"] as Double?
// val ColumnsContainer<_DataFrameType>.`Population - Labor force participation (%)`: DataColumn<String?> @JvmName("_DataFrameType_Population - Labor force participation (%)") get() = this["Population: Labor force participation (%)"] as DataColumn<String?>
// val DataRow<_DataFrameType>.`Population - Labor force participation (%)`: String? @JvmName("_DataFrameType_Population - Labor force participation (%)") get() = this["Population: Labor force participation (%)"] as String?
// val ColumnsContainer<_DataFrameType?>.`Population - Labor force participation (%)`: DataColumn<String?> @JvmName("Nullable_DataFrameType_Population - Labor force participation (%)") get() = this["Population: Labor force participation (%)"] as DataColumn<String?>
// val DataRow<_DataFrameType?>.`Population - Labor force participation (%)`: String? @JvmName("Nullable_DataFrameType_Population - Labor force participation (%)") get() = this["Population: Labor force participation (%)"] as String?
// val ColumnsContainer<_DataFrameType>.`Tax revenue (%)`: DataColumn<String?> @JvmName("_DataFrameType_Tax revenue (%)") get() = this["Tax revenue (%)"] as DataColumn<String?>
// val DataRow<_DataFrameType>.`Tax revenue (%)`: String? @JvmName("_DataFrameType_Tax revenue (%)") get() = this["Tax revenue (%)"] as String?
// val ColumnsContainer<_DataFrameType?>.`Tax revenue (%)`: DataColumn<String?> @JvmName("Nullable_DataFrameType_Tax revenue (%)") get() = this["Tax revenue (%)"] as DataColumn<String?>
// val DataRow<_DataFrameType?>.`Tax revenue (%)`: String? @JvmName("Nullable_DataFrameType_Tax revenue (%)") get() = this["Tax revenue (%)"] as String?
// val ColumnsContainer<_DataFrameType>.`Total tax rate`: DataColumn<String?> @JvmName("_DataFrameType_Total tax rate") get() = this["Total tax rate"] as DataColumn<String?>
// val DataRow<_DataFrameType>.`Total tax rate`: String? @JvmName("_DataFrameType_Total tax rate") get() = this["Total tax rate"] as String?
// val ColumnsContainer<_DataFrameType?>.`Total tax rate`: DataColumn<String?> @JvmName("Nullable_DataFrameType_Total tax rate") get() = this["Total tax rate"] as DataColumn<String?>
// val DataRow<_DataFrameType?>.`Total tax rate`: String? @JvmName("Nullable_DataFrameType_Total tax rate") get() = this["Total tax rate"] as String?
// val ColumnsContainer<_DataFrameType>.`Unemployment rate`: DataColumn<String?> @JvmName("_DataFrameType_Unemployment rate") get() = this["Unemployment rate"] as DataColumn<String?>
// val DataRow<_DataFrameType>.`Unemployment rate`: String? @JvmName("_DataFrameType_Unemployment rate") get() = this["Unemployment rate"] as String?
// val ColumnsContainer<_DataFrameType?>.`Unemployment rate`: DataColumn<String?> @JvmName("Nullable_DataFrameType_Unemployment rate") get() = this["Unemployment rate"] as DataColumn<String?>
// val DataRow<_DataFrameType?>.`Unemployment rate`: String? @JvmName("Nullable_DataFrameType_Unemployment rate") get() = this["Unemployment rate"] as String?
// (df as org.jetbrains.kotlinx.dataframe.DataFrame<*>).cast<_DataFrameType>()
//
// Errors:
// Line_7.jupyter.kts (68:39 - 46) Expecting property name
// Line_7.jupyter.kts (69:8 - 9) Expecting an element
// Line_7.jupyter.kts (69:9 - 10) Expecting an element
// Line_7.jupyter.kts (69:62 - 62) Expecting '"'
// Line_7.jupyter.kts (70:8 - 8) Expecting ','
// Line_7.jupyter.kts (71:8 - 8) Expecting ','
// Line_7.jupyter.kts (71:32 - 32) Expecting '"'
// Line_7.jupyter.kts (72:1 - 4) Expecting ')'
// Line_7.jupyter.kts (72:29 - 30) Expecting an element
// Line_7.jupyter.kts (73:8 - 9) Expecting an element
// Line_7.jupyter.kts (73:9 - 10) Expecting an element
// Line_7.jupyter.kts (73:50 - 50) Expecting '"'
// Line_7.jupyter.kts (74:8 - 8) Expecting ','
// Line_7.jupyter.kts (75:8 - 8) Expecting ','
// Line_7.jupyter.kts (75:20 - 20) Expecting '"'
// Line_7.jupyter.kts (76:1 - 4) Expecting ')'
// Line_7.jupyter.kts (76:39 - 40) Expecting an element
// Line_7.jupyter.kts (77:8 - 9) Expecting an element
// Line_7.jupyter.kts (77:9 - 10) Expecting an element
// Line_7.jupyter.kts (77:71 - 71) Expecting '"'
// Line_7.jupyter.kts (78:8 - 8) Expecting ','
// Line_7.jupyter.kts (79:8 - 8) Expecting ','
// Line_7.jupyter.kts (79:33 - 33) Expecting '"'
// Line_7.jupyter.kts (80:1 - 4) Expecting ')'
// Line_7.jupyter.kts (80:30 - 31) Expecting an element
// Line_7.jupyter.kts (81:8 - 9) Expecting an element
// Line_7.jupyter.kts (81:9 - 10) Expecting an element
// Line_7.jupyter.kts (81:17 - 18) Expecting an element
// Line_7.jupyter.kts (81:59 - 59) Expecting '"'
// Line_7.jupyter.kts (82:8 - 8) Expecting ','
// Line_7.jupyter.kts (83:8 - 8) Expecting ','
// Line_7.jupyter.kts (83:21 - 21) Expecting '"'
// Line_7.jupyter.kts (84:1 - 4) Expecting ')'
// Line_7.jupyter.kts (84:54 - 55) Expecting an element
//
// org.jetbrains.kotlinx.jupyter.exceptions.ReplLibraryException: The problem is found in one of the loaded libraries: check library converters (fields callbacks)
// 	at org.jetbrains.kotlinx.jupyter.exceptions.CompositeReplExceptionKt.throwLibraryException(CompositeReplException.kt:50)
// 	at org.jetbrains.kotlinx.jupyter.codegen.FieldsProcessorImpl.process(FieldsProcessorImpl.kt:68)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$1.invoke(CellExecutorImpl.kt:97)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$1.invoke(CellExecutorImpl.kt:96)
// 	at org.jetbrains.kotlinx.jupyter.config.LoggingKt.catchAll(logging.kt:42)
// 	at org.jetbrains.kotlinx.jupyter.config.LoggingKt.catchAll$default(logging.kt:41)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute(CellExecutorImpl.kt:96)
// 	at org.jetbrains.kotlinx.jupyter.repl.CellExecutor$DefaultImpls.execute$default(CellExecutor.kt:16)
// 	at org.jetbrains.kotlinx.jupyter.ReplForJupyterImpl$evalEx$1.invoke(repl.kt:496)
// 	at org.jetbrains.kotlinx.jupyter.ReplForJupyterImpl$evalEx$1.invoke(repl.kt:474)
// 	at org.jetbrains.kotlinx.jupyter.ReplForJupyterImpl.withEvalContext(repl.kt:437)
// 	at org.jetbrains.kotlinx.jupyter.ReplForJupyterImpl.evalEx(repl.kt:474)
// 	at org.jetbrains.kotlinx.jupyter.messaging.ProtocolKt$shellMessagesHandler$2$res$1.invoke(protocol.kt:320)
// 	at org.jetbrains.kotlinx.jupyter.messaging.ProtocolKt$shellMessagesHandler$2$res$1.invoke(protocol.kt:314)
// 	at org.jetbrains.kotlinx.jupyter.JupyterExecutorImpl$runExecution$execThread$1.invoke(execution.kt:38)
// 	at org.jetbrains.kotlinx.jupyter.JupyterExecutorImpl$runExecution$execThread$1.invoke(execution.kt:33)
// 	at kotlin.concurrent.ThreadsKt$thread$thread$1.run(Thread.kt:30)
// Caused by: org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: Line_7.jupyter.kts (68:39 - 46) Expecting property name
// Line_7.jupyter.kts (69:8 - 9) Expecting an element
// Line_7.jupyter.kts (69:9 - 10) Expecting an element
// Line_7.jupyter.kts (69:62 - 62) Expecting '"'
// Line_7.jupyter.kts (70:8 - 8) Expecting ','
// Line_7.jupyter.kts (71:8 - 8) Expecting ','
// Line_7.jupyter.kts (71:32 - 32) Expecting '"'
// Line_7.jupyter.kts (72:1 - 4) Expecting ')'
// Line_7.jupyter.kts (72:29 - 30) Expecting an element
// Line_7.jupyter.kts (73:8 - 9) Expecting an element
// Line_7.jupyter.kts (73:9 - 10) Expecting an element
// Line_7.jupyter.kts (73:50 - 50) Expecting '"'
// Line_7.jupyter.kts (74:8 - 8) Expecting ','
// Line_7.jupyter.kts (75:8 - 8) Expecting ','
// Line_7.jupyter.kts (75:20 - 20) Expecting '"'
// Line_7.jupyter.kts (76:1 - 4) Expecting ')'
// Line_7.jupyter.kts (76:39 - 40) Expecting an element
// Line_7.jupyter.kts (77:8 - 9) Expecting an element
// Line_7.jupyter.kts (77:9 - 10) Expecting an element
// Line_7.jupyter.kts (77:71 - 71) Expecting '"'
// Line_7.jupyter.kts (78:8 - 8) Expecting ','
// Line_7.jupyter.kts (79:8 - 8) Expecting ','
// Line_7.jupyter.kts (79:33 - 33) Expecting '"'
// Line_7.jupyter.kts (80:1 - 4) Expecting ')'
// Line_7.jupyter.kts (80:30 - 31) Expecting an element
// Line_7.jupyter.kts (81:8 - 9) Expecting an element
// Line_7.jupyter.kts (81:9 - 10) Expecting an element
// Line_7.jupyter.kts (81:17 - 18) Expecting an element
// Line_7.jupyter.kts (81:59 - 59) Expecting '"'
// Line_7.jupyter.kts (82:8 - 8) Expecting ','
// Line_7.jupyter.kts (83:8 - 8) Expecting ','
// Line_7.jupyter.kts (83:21 - 21) Expecting '"'
// Line_7.jupyter.kts (84:1 - 4) Expecting ')'
// Line_7.jupyter.kts (84:54 - 55) Expecting an element
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl.compileSync(JupyterCompilerImpl.kt:182)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.InternalEvaluatorImpl.eval(InternalEvaluatorImpl.kt:102)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:76)
// 	at org.jetbrains.kotlinx.jupyter.ReplForJupyterImpl.withHost(repl.kt:681)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute(CellExecutorImpl.kt:76)
// 	at org.jetbrains.kotlinx.jupyter.repl.CellExecutor$DefaultImpls.execute$default(CellExecutor.kt:16)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext.execute(CellExecutorImpl.kt:231)
// 	at org.jetbrains.kotlinx.dataframe.jupyter.Integration.execute(Integration.kt:83)
// 	at org.jetbrains.kotlinx.dataframe.jupyter.Integration.execute(Integration.kt:96)
// 	at org.jetbrains.kotlinx.dataframe.jupyter.Integration.updateAnyFrameVariable(Integration.kt:131)
// 	at org.jetbrains.kotlinx.dataframe.jupyter.Integration.access$updateAnyFrameVariable(Integration.kt:73)
// 	at org.jetbrains.kotlinx.dataframe.jupyter.Integration$onLoaded$4.invoke(Integration.kt:295)
// 	at org.jetbrains.kotlinx.dataframe.jupyter.Integration$onLoaded$4.invoke(Integration.kt:290)
// 	at org.jetbrains.kotlinx.jupyter.api.libraries.FieldHandlerFactory.createUpdateExecution$lambda$0(FieldHandlerFactory.kt:38)
// 	at org.jetbrains.kotlinx.jupyter.codegen.FieldsProcessorImplKt.executeEx(FieldsProcessorImpl.kt:88)
// 	at org.jetbrains.kotlinx.jupyter.codegen.FieldsProcessorImplKt.access$executeEx(FieldsProcessorImpl.kt:1)
// 	at org.jetbrains.kotlinx.jupyter.codegen.FieldsProcessorImpl.process(FieldsProcessorImpl.kt:47)
// 	... 15 more
//             <iframe onload="o_resize_iframe_out_1()" style="width:100%;" class="result_container" id="iframe_out_1" frameBorder="0" srcdoc="        &lt;html&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody &gt; tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody &gt; tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody &gt; tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover &gt; td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// &sol;* formatting *&sol;
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
// :root {
//     --scroll-bg: #f5f5f5;
//     --scroll-fg: #b3b3b3;
// }
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;]{
//     --scroll-bg: #3c3c3c;
//     --scroll-fg: #97e1fb;
// }
// body {
//     scrollbar-color: var(--scroll-fg) var(--scroll-bg);
// }
// body::-webkit-scrollbar {
//     width: 10px; &sol;* Mostly for vertical scrollbars *&sol;
//     height: 10px; &sol;* Mostly for horizontal scrollbars *&sol;
// }
// body::-webkit-scrollbar-thumb {
//     background-color: var(--scroll-fg);
// }
// body::-webkit-scrollbar-track {
//     background-color: var(--scroll-bg);
// }
//             &lt;&sol;style&gt;
//         &lt;&sol;head&gt;
//         &lt;body&gt;
//
// &lt;table class=&quot;dataframe&quot; id=&quot;df_486539264&quot;&gt;&lt;&sol;table&gt;
//
// &lt;p class=&quot;dataframe_description&quot;&gt;DataFrame: rowsCount = 5, columnsCount = 35&lt;&sol;p&gt;
//
//         &lt;&sol;body&gt;
//         &lt;script&gt;
//             (function () {
//     window.DataFrame = window.DataFrame || new (function () {
//         this.addTable = function (df) {
//             let cols = df.cols;
//             for (let i = 0; i &lt; cols.length; i++) {
//                 for (let c of cols[i].children) {
//                     cols[c].parent = i;
//                 }
//             }
//             df.nrow = 0
//             for (let i = 0; i &lt; df.cols.length; i++) {
//                 if (df.cols[i].values.length &gt; df.nrow) df.nrow = df.cols[i].values.length
//             }
//             if (df.id === df.rootId) {
//                 df.expandedFrames = new Set()
//                 df.childFrames = {}
//                 const table = this.getTableElement(df.id)
//                 table.df = df
//                 for (let i = 0; i &lt; df.cols.length; i++) {
//                     let col = df.cols[i]
//                     if (col.parent === undefined &amp;&amp; col.children.length &gt; 0) col.expanded = true
//                 }
//             } else {
//                 const rootDf = this.getTableData(df.rootId)
//                 rootDf.childFrames[df.id] = df
//             }
//         }
//
//         this.computeRenderData = function (df) {
//             let result = []
//             let pos = 0
//             for (let col = 0; col &lt; df.cols.length; col++) {
//                 if (df.cols[col].parent === undefined)
//                     pos += this.computeRenderDataRec(df.cols, col, pos, 0, result, false, false)
//             }
//             for (let i = 0; i &lt; result.length; i++) {
//                 let row = result[i]
//                 for (let j = 0; j &lt; row.length; j++) {
//                     let cell = row[j]
//                     if (j === 0)
//                         cell.leftBd = false
//                     if (j &lt; row.length - 1) {
//                         let nextData = row[j + 1]
//                         if (nextData.leftBd) cell.rightBd = true
//                         else if (cell.rightBd) nextData.leftBd = true
//                     } else cell.rightBd = false
//                 }
//             }
//             return result
//         }
//
//         this.computeRenderDataRec = function (cols, colId, pos, depth, result, leftBorder, rightBorder) {
//             if (result.length === depth) {
//                 const array = [];
//                 if (pos &gt; 0) {
//                     let j = 0
//                     for (let i = 0; j &lt; pos; i++) {
//                         let c = result[depth - 1][i]
//                         j += c.span
//                         let copy = Object.assign({empty: true}, c)
//                         array.push(copy)
//                     }
//                 }
//                 result.push(array)
//             }
//             const col = cols[colId];
//             let size = 0;
//             if (col.expanded) {
//                 let childPos = pos
//                 for (let i = 0; i &lt; col.children.length; i++) {
//                     let child = col.children[i]
//                     let childLeft = i === 0 &amp;&amp; (col.children.length &gt; 1 || leftBorder)
//                     let childRight = i === col.children.length - 1 &amp;&amp; (col.children.length &gt; 1 || rightBorder)
//                     let childSize = this.computeRenderDataRec(cols, child, childPos, depth + 1, result, childLeft, childRight)
//                     childPos += childSize
//                     size += childSize
//                 }
//             } else {
//                 for (let i = depth + 1; i &lt; result.length; i++)
//                     result[i].push({id: colId, span: 1, leftBd: leftBorder, rightBd: rightBorder, empty: true})
//                 size = 1
//             }
//             let left = leftBorder
//             let right = rightBorder
//             if (size &gt; 1) {
//                 left = tru

// %%
df.describe()
// Out:
//             <iframe onload="o_resize_iframe_out_3()" style="width:100%;" class="result_container" id="iframe_out_3" frameBorder="0" srcdoc="        &lt;html&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody &gt; tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody &gt; tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody &gt; tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover &gt; td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// &sol;* formatting *&sol;
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
// :root {
//     --scroll-bg: #f5f5f5;
//     --scroll-fg: #b3b3b3;
// }
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;]{
//     --scroll-bg: #3c3c3c;
//     --scroll-fg: #97e1fb;
// }
// body {
//     scrollbar-color: var(--scroll-fg) var(--scroll-bg);
// }
// body::-webkit-scrollbar {
//     width: 10px; &sol;* Mostly for vertical scrollbars *&sol;
//     height: 10px; &sol;* Mostly for horizontal scrollbars *&sol;
// }
// body::-webkit-scrollbar-thumb {
//     background-color: var(--scroll-fg);
// }
// body::-webkit-scrollbar-track {
//     background-color: var(--scroll-bg);
// }
//             &lt;&sol;style&gt;
//         &lt;&sol;head&gt;
//         &lt;body&gt;
//
// &lt;table class=&quot;dataframe&quot; id=&quot;df_1694498818&quot;&gt;&lt;&sol;table&gt;
//
// &lt;p class=&quot;dataframe_description&quot;&gt;... showing only top 20 of 35 rows&lt;&sol;p&gt;&lt;p class=&quot;dataframe_description&quot;&gt;DataFrame: rowsCount = 35, columnsCount = 12&lt;&sol;p&gt;
//
//         &lt;&sol;body&gt;
//         &lt;script&gt;
//             (function () {
//     window.DataFrame = window.DataFrame || new (function () {
//         this.addTable = function (df) {
//             let cols = df.cols;
//             for (let i = 0; i &lt; cols.length; i++) {
//                 for (let c of cols[i].children) {
//                     cols[c].parent = i;
//                 }
//             }
//             df.nrow = 0
//             for (let i = 0; i &lt; df.cols.length; i++) {
//                 if (df.cols[i].values.length &gt; df.nrow) df.nrow = df.cols[i].values.length
//             }
//             if (df.id === df.rootId) {
//                 df.expandedFrames = new Set()
//                 df.childFrames = {}
//                 const table = this.getTableElement(df.id)
//                 table.df = df
//                 for (let i = 0; i &lt; df.cols.length; i++) {
//                     let col = df.cols[i]
//                     if (col.parent === undefined &amp;&amp; col.children.length &gt; 0) col.expanded = true
//                 }
//             } else {
//                 const rootDf = this.getTableData(df.rootId)
//                 rootDf.childFrames[df.id] = df
//             }
//         }
//
//         this.computeRenderData = function (df) {
//             let result = []
//             let pos = 0
//             for (let col = 0; col &lt; df.cols.length; col++) {
//                 if (df.cols[col].parent === undefined)
//                     pos += this.computeRenderDataRec(df.cols, col, pos, 0, result, false, false)
//             }
//             for (let i = 0; i &lt; result.length; i++) {
//                 let row = result[i]
//                 for (let j = 0; j &lt; row.length; j++) {
//                     let cell = row[j]
//                     if (j === 0)
//                         cell.leftBd = false
//                     if (j &lt; row.length - 1) {
//                         let nextData = row[j + 1]
//                         if (nextData.leftBd) cell.rightBd = true
//                         else if (cell.rightBd) nextData.leftBd = true
//                     } else cell.rightBd = false
//                 }
//             }
//             return result
//         }
//
//         this.computeRenderDataRec = function (cols, colId, pos, depth, result, leftBorder, rightBorder) {
//             if (result.length === depth) {
//                 const array = [];
//                 if (pos &gt; 0) {
//                     let j = 0
//                     for (let i = 0; j &lt; pos; i++) {
//                         let c = result[depth - 1][i]
//                         j += c.span
//                         let copy = Object.assign({empty: true}, c)
//                         array.push(copy)
//                     }
//                 }
//                 result.push(array)
//             }
//             const col = cols[colId];
//             let size = 0;
//             if (col.expanded) {
//                 let childPos = pos
//                 for (let i = 0; i &lt; col.children.length; i++) {
//                     let child = col.children[i]
//                     let childLeft = i === 0 &amp;&amp; (col.children.length &gt; 1 || leftBorder)
//                     let childRight = i === col.children.length - 1 &amp;&amp; (col.children.length &gt; 1 || rightBorder)
//                     let childSize = this.computeRenderDataRec(cols, child, childPos, depth + 1, result, childLeft, childRight)
//                     childPos += childSize
//                     size += childSize
//                 }
//             } else {
//                 for (let i = depth + 1; i &lt; result.length; i++)
//                     result[i].push({id: colId, span: 1, leftBd: leftBorder, rightBd: rightBorder, empty: true})
//                 size = 1
//             }
//             let left = leftB
